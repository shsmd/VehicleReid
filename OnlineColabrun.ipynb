# %% [markdown]
# <a href="https://colab.research.google.com/github/shsmd/VehicleReid/blob/main/OnlineColabrun.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#mount google drive, clone provided code base
import os
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !git clone https://github.com/Surrey-EEEM071-CVDL/EEEM071-Coursework-2025
# Out:
# Cloning into 'EEEM071-Coursework-2025'...
# remote: Enumerating objects: 55, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (21/21), done.
# remote: Total 55 (delta 7), reused 3 (delta 3), pack-reused 31 (from 1)
# Receiving objects: 100% (55/55), 33.67 KiB | 11.22 MiB/s, done.
# Resolving deltas: 100% (7/7), done.

# %%
#access dataset (zipped in google drive, dataset from Large-scale vehicle re-identification in urban surveillance videos)
# !unzip -o /content/drive/MyDrive/Comp_Vision/CW/VeRi.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: VeRi/image_train/0474_c001_00028990_1.jpg
#   inflating: VeRi/image_train/0223_c010_00086140_0.jpg
#   inflating: VeRi/image_train/0603_c011_00022435_0.jpg
#   inflating: VeRi/image_train/0161_c001_00026185_0.jpg
#   inflating: VeRi/image_train/0426_c001_00050530_0.jpg
#   inflating: VeRi/image_train/0164_c004_00000070_1.jpg
#   inflating: VeRi/image_train/0544_c006_00012315_0.jpg
#   inflating: VeRi/image_train/0381_c001_00061900_0.jpg
#   inflating: VeRi/image_train/0243_c015_00031655_1.jpg
#   inflating: VeRi/image_train/0366_c004_00079340_0.jpg
#   inflating: VeRi/image_train/0223_c001_00083620_0.jpg
#   inflating: VeRi/image_train/0321_c001_00088780_1.jpg
#   inflating: VeRi/image_train/0022_c004_00072370_0.jpg
#   inflating: VeRi/image_train/0572_c010_00053425_0.jpg
#   inflating: VeRi/image_train/0514_c016_00041710_0.jpg
#   inflating: VeRi/image_train/0769_c003_00071340_0.jpg
# ...

# %%
#Change directory to Coursework
# %cd /content/EEEM071-Coursework-2025
# Out:
# /content/EEEM071-Coursework-2025

# %%
#Make train.sh into an executable and run script using bash shell
# !chmod +x /content/EEEM071-Coursework-2025/train.sh
# !bash /content/EEEM071-Coursework-2025/train.sh
# Out:
# ...
# Student ID:1234567
# Student name:shsmd
# UUID:4f941deb-dde3-4a2b-b964-e3135ed4a369
# Experiment time:2025-07-17 17:55:25
# ...
# Args:Namespace(root='/content', source_names=['veri'], target_names=['veri'], workers=4, split_id=0, height=224, width=224, train_sampler='RandomSampler', random_erase=True, color_jitter=False, color_aug=True, optim='amsgrad', lr=0.0001, weight_decay=0.0005, momentum=0.9, sgd_dampening=0, sgd_nesterov=False, rmsprop_alpha=0.99, adam_beta1=0.9, adam_beta2=0.999, max_epoch=10, start_epoch=0, train_batch_size=128, test_batch_size=100, lr_scheduler='multi_step', stepsize=[20, 40], gamma=0.1, label_smooth=False, margin=0.3, num_instances=4, lambda_xent=1, lambda_htri=1, arch='resnet50_fc512', no_pretrained=False, load_weights='', evaluate=False, eval_freq=-1, start_eval=0, test_size=800, query_remove=True, print_freq=10, seed=1, resume='', save_dir='logs/resnet50_fc512', use_cpu=False, gpu_devices='0', visualize_ranks=False, use_avai_gpus=False)
# ...
